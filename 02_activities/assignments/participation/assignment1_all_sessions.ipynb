# %% [markdown]
# # Session 1

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x=np.arange(50)
y=np.random.randint(0,100,50)

# %%
fig, ax=plt.subplots(figsize=(5,3))
ax.scatter(x,y)

# %%
fig, ax = plt.subplots(figsize= (5,3))
ax.plot(x,y)

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig,ax=plt.subplots(figsize= (5,3))
ax.plot(x,y)
ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
fig.tight_layout()

# %%
font1={'family': 'sans-serif', 'color':'blue','size' :20}
font2={'family': 'monospace', 'color':'green', 'size':14}

# %%
fig,ax=plt.subplots(figsize= (5,3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict= font1)
ax.set_ylabel('Total growth', fontdict= font2)
ax.set_xlabel('Years since start', fontdict= font2)
fig.tight_layout()

# %%
fig, ax=plt.subplots(figsize=(5,3))
ax.scatter(x,y, marker='*', color='indigo')
fig.show()
# Out:
# /var/folders/pp/15688hb13sl1hnpnxgw_mw3c0000gn/T/ipykernel_21139/3058718406.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# # Live session 2

# %%
#Second activity

# %%
plt.rcParams['figure.dpi'] = 300

# %%
hours = [17, 20, 22, 25, 26, 27, 30, 31, 32, 38, 40, 40, 45, 55]

# %%
fig, ax = plt.subplots(figsize = (9, 6))
ax.hist(hours, bins=5, edgecolor="black")
plt.show()

# %% [markdown]
# Activity
#
# Aesthetic: While it is not particularly aesthetically pleasing, it is clean and the color isn't sore to eyes.
# Substantive: the histogram presents data accurately, without any distortion. However, the spacing of the x-axis numbers doesn't match the width of the columns.
# Perceptual: The data is about weekly hours of work reported by people. In the histogram, there isn't any title, or legends, failing to convey the message.

# %% [markdown]
# # Session 3 Activity

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0,100,50)
y2 = np.random.randint(0,100,50)

# %%
fig, ax = plt.subplots(figsize= (5,3))
ax.plot(x,y1, label = "Person1")
ax.plot(x,y2, label = "Person2")
ax.legend(loc ='lower right',
          frameon= True,
          fontsize = 12,
          ncol =  2,
          shadow = True
          )

# %%
fig, ax = plt.subplots(figsize= (5,3))
ax.plot(x,y1, label = "Person1")
ax.plot(x,y2, label = "Person2")
ax.legend(loc ='upper left',
          bbox_to_anchor =(1,1)
          )

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = "lower right")
ax.text(10,95, "This value is important!",
        ha = 'left',
        color = 'red',
        size = 20)
# Out:
# Text(10, 95, 'This value is important!')

# %%
fig, ax= plt.subplots()
ax.axis([0,10,0,10])
# Out:
# (np.float64(0.0), np.float64(10.0), np.float64(0.0), np.float64(10.0))

# %%
fig, ax= plt.subplots()
ax.axis([0,10,0,10])
ax.text(1,5,".Data:(1,5)", transform =ax.transData)
ax.text(0.5,0.1, ".Axes(0.5,0.1)", transform = ax.transAxes)
ax.text(0.2,0.2, ".Figure:(0.2, 0.2)", transform= fig.transFigure)
# Out:
# Text(0.2, 0.2, '.Figure:(0.2, 0.2)')

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = "lower right")

ax.annotate('This value is important!', xy=(10,94),
            xytext=(15,97),
            arrowprops= dict(facecolor = 'black'))
# Out:
# Text(15, 97, 'This value is important!')

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = "lower right")

ax.annotate('This value is important!', xy=(10,94),
            xytext=(15,97),
            arrowprops= dict(arrowstyle="wedge", color = "red"))
# Out:
# Text(15, 97, 'This value is important!')

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = "lower right")

ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = "lower right")
ax.xaxis.set_major_locator(plt.MaxNLocator(3))

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x,y1, label = "Person 1") #scattor plot for person1
ax.scatter(x,y2, label = "Person 2") #scattor plot for person2
ax.legend(loc = "lower right")
ax.xaxis.set_major_locator(plt.MultipleLocator(15))

# %%
font1={'family': 'serif', 'color':'indigo','size' :12}

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = "lower right") # locate the legend at the bottom right
ax.xaxis.set_major_locator(plt.MultipleLocator(10)) #set automatic ticks with a distance of 10
plt.xticks(rotation = 45, ha= 'right') #rotate the xticks to 45 degree
plt.xlabel("Shiny New X Axis!", fontsize = 18, fontdict= font1) #create a title
# Out:
# Text(0.5, 0, 'Shiny New X Axis!')

# %%
plt.style.available #check what are the available styles
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-deep') #use existing style seaborn v0_8
fig, ax = plt.subplots(figsize = (5,3))
ax.plot(x,y1)
ax.plot(x,y2)

# %% [markdown]
# Activity: Comment our code
# - What information is helpful to include?: A short explanation of the code, including the intended result of the code is helpful to include. The source of data can also be included.
#
# - How do you write a 'good' comment?; in my opinion, a good comment is a simple,short, but clearly described comment without a jargon.

# %% [markdown]
# # Session 4
# Activity: In what ways is this data visualization inaccessible, and to whom? Letʼs discuss!
# - the use of colors in this visualization can be very confusing for those with color blind and eye impairment. Firstly, for those who cannot see the red color, the point of the immidiate interventions can be easily overlooked, making it difficult to understand. Secondly, the description of the graph for the case of control measures is located too closely with another description, being another source of confusion.
#
# Activity: What would be suitable alt-text for this image?
# - A journalist(behind) discussing with a researcher in the laboratory(front)

# %%
np.random.seed(613)
x1 = np.arange(50)
y1 = np.random.randint(0, 75, 50)
x2 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y2 = np.array([110, 180, 240, 99, 220])

# %%
plt.style.use('ggplot')
fig,(ax1, ax2) = plt.subplots(ncols =2,
                               nrows =1,
                               figsize = (7,3))

ax1.scatter(x1,y1)
ax2.bar(x2,y2)
# Out:
# <BarContainer object of 5 artists>

# %%
#Activity: Customizing our plots

plt.style.use('seaborn-v0_8-whitegrid')
font2={'family': 'Serif', 'color':'black','size' :9}
fig,(ax1, ax2) = plt.subplots(ncols =2,
                               nrows =1,
                               figsize = (7,3))
ax1.scatter(x1,y1)
ax1.annotate("Zoro", xy=(20,40), xytext= (25,45),arrowprops=dict(arrowstyle="wedge", color = "red"))
ax1.set_title("The scatter plot", fontsize = 15, fontdict= font2)
ax2.bar(x2,y2)
ax2.set_title("The distribution of scores", fontsize = 15, fontdict= font2)
# Out:
# Text(0.5, 1.0, 'The distribution of scores')

# %%
plt.style.use('default')
fig,someaxes =plt.subplot_mosaic([['ax1', 'ax3'], 
                                   ['ax2', 'ax3']],
                                  figsize= (7,4))
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)
someaxes["ax1"].set_xlabel('A Big Label',fontsize=18)
someaxes["ax2"].set_xlabel('Another Label',fontsize=18)
someaxes["ax3"].set_xlabel('Label 2: 2 Fast 2 Furious',fontsize=18)
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %%
x=np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1= np.array([110, 180, 240, 99, 220])
y2= np.array([170, 100, 90, 120, 50])

fig, ax = plt.subplots(figsize=(7, 3))
ax.bar(x, y1, color = "indigo")
ax.plot(x, y2, color = "red")

# %%
y2_sd = np.std(y2)
fig,ax=plt.subplots(figsize = (7, 3))
ax.plot(x,y2, color = "red")

# %%
fig,ax=plt.subplots(figsize = (7, 3))
ax.plot(x,y2, color = "red")
ax.errorbar(x, y2,
            yerr= y2_sd,
            fmt= "none",
            ecolor = 'indigo',
            elinewidth= 4,
            capsize= 6,
            capthick=4,
            errorevery= 1)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
from PIL import Image 
import requests 
from io import BytesIO 

url = "https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png"
headers = {"User-Agent": "Mozilla/5.0","Accept": "image/*,*/*;q=0.8","Referer": "https://en.wikipedia.org/"}
response = requests.get(url, headers=headers)
image_file = BytesIO(response.content)
image = Image.open(image_file)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=220x426>

# %%
fig,ax=plt.subplots(figsize = (7, 3))
ax.plot(x,y2, color = "red")
ax_image = fig.add_axes([0.1,
                         0.11,
                         0.15,
                         0.35])
ax_image.imshow(image)
ax_image.axis('off')

path='/Users/jinrikim/Desktop/DSI/visualization/02_activities/assignments/participation'
filename = 'fig1a.png'

plt.savefig(path+filename, dpi = 300)

# %% [markdown]
# # Session 5
#
# Activity: How did this diagram of the Brooks use rational, moral, and emotional appeal to make a case to its audiences?
# - rational: they give a very specific number of slaves in the ship
# - moral: in the visual description, it shows how inhumane the conditions within the ship
# - emotional: the image evokes anger and indignation.

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tipgraph = sns.lineplot(data=tips,
x='total_bill',
y='tip',
color = 'hotpink',
linestyle = '--',
linewidth = 3,
marker = 'o',
markerfacecolor = 'indigo')

tipgraph.set(title='Tips vs. Total Bill', xlabel='Total Bill ($)', ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
tipgraph = sns.scatterplot(data=tips, x='total_bill',
y='tip', style = 'time', hue ='day', palette = ['purple','hotpink', 'deepskyblue','yellowgreen']) 

tipgraph.set(title='Tips vs. Total Bill',
    xlabel = 'Total Bill ($)',
    ylabel = 'Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
sns.pairplot(
    data = tips,
    hue = 'day')

# %%
daysplot= sns.relplot(data= tips,
                      x= "total_bill",
                      y= "tip",
                      hue="sex",
                      col="day",
                      kind="scatter",
                      col_wrap= 2)

# %% [markdown]
#  Activity: Comparing data visualizations
# - How are they different? what does each visualization do?: the left one is static visualization while the right one is a dynamic visualization.
# - What are the pros and cons of each? the left one is less engaging compared to the dynmaic one. However, the intended message may be better passed through a right one without misunderstanding. On the other hand, the dynmaic visualization can be confusing or overwhelming for audience.
#
# Activity: Types of changes
# - What types of changes occur when we interact with this dynamic data visualization? immediate change
# - Which spatial and retinal elements stay constant? Which change? Size of the visualization, brightness, patterning, shape and color.
# - If you were redesigning this viz, would you choose to make different changes? Why or why not? I woud not. Because the message that the visualization tries to convey is not the comparisons between different words, but how language use in the teacher reviews is gendered.

# %%
import plotly.graph_objects as go
from wordcloud import WordCloud
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
x1 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

# %%
graph= go.Figure()
graph.add_trace(go.Bar(x=x1, y= y1))
graph.update_layout(title="Pirate Scores",
                    xaxis_title="Pirates",
                    yaxis_title="Score")

# %%
graph=go.Figure()
graph.add_trace(go.Scatter(x=x1, y=y1, mode='markers',
                marker=dict(size= 15, color='hotpink', 
                        opacity=1, line=dict(width=5, color='purple'))))
graph.update_layout(
title='Interactive Pirate Plot',
xaxis_title='Pirates',
yaxis_title='Scores',
width=500, height=500)

# %%
from wordcloud import WordCloud
df = pd.read_csv("movie_quotes.csv")
df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# ...

# %%
from wordcloud import WordCloud
text = "".join(each for each in df.quote)

wordcloud = WordCloud(background_color="white",colormap= 'inferno').generate(text)

fig,ax = plt.subplots(figsize =(7,3))
ax.imshow(wordcloud, interpolation= 'bilinear')
ax.axis("off")
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))

# %%
A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])

diagram = venn2_unweighted([A, B],
                           set_labels = ('Fruits', 'Pies'),
                           set_colors=("blue", "red"),
                           alpha=0.5)
diagram.get_label_by_id("10").set_text("\n".join(A - B))
diagram.get_label_by_id("11").set_text("\n".join(A & B))
diagram.get_label_by_id("01").set_text("\n".join(B - A))
